# %% [markdown]
# The below will be used to download **S&P 500** options data.

# %%
from yahoo_fin import options
import pandas as pd
from datetime import datetime

import requests
from requests.exceptions import ConnectionError

# %%
spx_dates = options.get_expiration_dates("^SPX")
spx_dates
# Out:
# ['July 10, 2023',
#  'July 11, 2023',
#  'July 12, 2023',
#  'July 13, 2023',
#  'July 14, 2023',
#  'July 17, 2023',
#  'July 18, 2023',
#  'July 19, 2023',
#  'July 20, 2023',
#  'July 21, 2023',
#  'July 24, 2023',
#  'July 25, 2023',
#  'July 26, 2023',
#  'July 27, 2023',
#  'July 28, 2023',
#  'July 31, 2023',
#  'August 1, 2023',
#  'August 2, 2023',
#  'August 3, 2023',
#  'August 4, 2023',
#  'August 7, 2023',
#  'August 8, 2023',
#  'August 11, 2023',
#  'August 18, 2023',
#  'August 25, 2023',
#  'August 31, 2023',
#  'September 15, 2023',
#  'September 29, 2023',
#  'October 20, 2023',
#  'October 31, 2023',
#  'November 17, 2023',
#  'November 30, 2023',
#  'December 15, 2023',
#  'December 29, 2023',
#  'January 19, 2024',
#  'February 16, 2024',
#  'March 15, 2024',
#  'March 28, 2024',
#  'April 19, 2024',
#  'May 17, 2024',
#  'June 21, 2024',
#  'June 28, 2024',
#  'July 19, 2024',
#  'September 20, 2024',
#  'December 20, 2024',
#  'June 20, 2025',
#  'December 19, 2025',
#  'March 20, 2026',
#  'December 18, 2026',
#  'December 17, 2027',
#  'December 15, 2028']

# %%
dates = ['July 14, 2023','August 18, 2023','September 15, 2023','October 20, 2023','November 17, 2023',
        'December 15, 2023','January 19, 2024','February 16, 2024','March 15, 2024','April 19, 2024','May 17, 2024',
 'June 21, 2024','July 19, 2024',
 'September 20, 2024',
 'December 20, 2024']

# %%
len(dates)
# Out:
# 15

# %%
symbol = "^SPX"
max_attempts = 3
attempt = 1
spx_calls = {}

for i in dates:
    while attempt <= max_attempts:
        try:
            spx_option_data = options.get_calls(symbol,i)
            break
        except (ConnectionError, requests.Timeout):
            print(f"Attempt {attempt} failed. Retrying...")
            attempt += 1

    if attempt > max_attempts:
        print("Max number of attempts reached. Unable to retrieve data.")
    else:
        spx_calls[i] = spx_option_data
        spx_calls[i]['Expiration'] = i

# %% [markdown]
# In the code above the options data is downloaded and stored in the dictionary spx_calls, with the expiration dates added as an extra column.

# %%
spx_calls[dates[14]]
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price      Bid  \
# 0   SPX241220C00200000  2023-07-07 12:49PM EDT   200.0     4168.90  4130.90
# 1   SPX241220C00400000   2023-06-29 3:10PM EDT   400.0     3942.27  3946.00
# 2   SPX241220C00600000   2023-07-03 9:46AM EDT   600.0     3815.90  3761.30
# 3   SPX241220C00800000   2023-06-29 3:08PM EDT   800.0     3573.90  3576.90
# 4   SPX241220C01000000   2023-07-06 3:43PM EDT  1000.0     3437.85  3392.60
# ..                 ...                     ...     ...         ...      ...
# 68  SPX241220C08400000   2023-06-23 1:37PM EDT  8400.0        0.12     0.05
# 69  SPX241220C08600000  2023-06-21 10:23AM EDT  8600.0        0.20     0.00
# 70  SPX241220C08800000  2023-07-05 11:07AM EDT  8800.0        0.10     0.00
# 71  SPX241220C09000000  2023-07-05 11:07AM EDT  9000.0        0.10     0.00
# 72  SPX241220C09200000   2023-07-10 9:35AM EDT  9200.0        0.10     0.05
#
#         Ask  Change % Change Volume  Open Interest Implied Volatility  \
# 0   4150.70     0.0        -      5           2158              0.00%
# 1   3965.80     0.0        -      4           2808              0.00%
# 2   3781.10     0.0        -      2           2542              0.00%
# 3   3596.60     0.0        -      2           3001              0.00%
# 4   3412.30     0.0        -      1           8409             55.74%
# ..      ...     ...      ...    ...            ...                ...
# 68     0.40     0.0        -     10            239             17.52%
# 69     0.20     0.0        -      1            242             17.12%
# 70     0.35     0.0        -    135           4391             18.43%
# 71     0.10     0.0        -    120           3903             17.27%
# 72     0.10     0.0        -     26           9618             17.75%
#
#            Expiration
# 0   December 20, 2024
# 1   December 20, 2024
# 2   December 20, 2024
# 3   December 20, 2024
# 4   December 20, 2024
# ..                ...
# 68  December 20, 2024
# 69  December 20, 2024
# 70  December 20, 2024
# 71  December 20, 2024
# 72  December 20, 2024
#
# [73 rows x 12 columns]

# %%
spx_calls[dates[3]]
# Out:
#            Contract Name         Last Trade Date  Strike  Last Price     Bid  \
# 0    SPXW231020C00200000  2023-07-07 10:18AM EDT   200.0     4197.59  4192.1
# 1    SPXW231020C00400000  2023-06-28 10:22AM EDT   400.0     3961.29  3994.6
# 2    SPXW231020C00600000   2023-06-27 2:20PM EDT   600.0     3774.80  3798.5
# 3     SPX231020C00800000  2023-05-23 11:53AM EDT   800.0     3379.00     0.0
# 4     SPX231020C01000000   2023-06-20 3:30PM EDT  1000.0     3392.20  3404.1
# ..                   ...                     ...     ...         ...     ...
# 222  SPXW231020C06000000  2023-06-09 11:29AM EDT  6000.0        0.05     0.0
# 223   SPX231020C06200000  2023-07-10 12:00PM EDT  6200.0        0.07     0.0
# 224   SPX231020C06400000   2023-06-06 3:13PM EDT  6400.0        0.06     0.0
# 225  SPXW231020C06600000  2023-05-25 10:39AM EDT  6600.0        0.07     0.0
# 226   SPX231020C06800000  2023-07-10 12:01PM EDT  6800.0        0.05     0.0
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility  \
# 0    4196.10    0.00        -      2            167              0.00%
# 1    3998.60    0.00        -      3             61              0.00%
# 2    3802.50    0.00        -      6             40              0.00%
# 3       0.00    0.00        -      2              0              0.00%
# 4    3409.40    0.00        -   2500           2583            100.39%
# ..       ...     ...      ...    ...            ...                ...
# 222     0.15    0.00        -     10             90             18.90%
# 223     0.10   -0.01  -12.50%      2            250             20.04%
# 224     0.10    0.00        -      8            382             21.73%
# 225     0.10    0.00        -      -              2             23.34%
# 226     0.05   -0.02  -28.57%      4            417             23.73%
#
#            Expiration
# 0    October 20, 2023
# 1    October 20, 2023
# 2    October 20, 2023
# 3    October 20, 2023
# 4    October 20, 2023
# ..                ...
# 222  October 20, 2023
# 223  October 20, 2023
# 224  October 20, 2023
# 225  October 20, 2023
# 226  October 20, 2023
#
# [227 rows x 12 columns]

# %% [markdown]
# So data is stored in such a way that the options expiring on date "i" are stored as a dataframe with the name spx_calls[dates[i]].

# %%
#storing all dataframes in an array
dfs = [spx_calls[dates[i]] for i in range(len(dates))]

# %%
len(dfs)
dfs[3]
# Out:
#            Contract Name         Last Trade Date  Strike  Last Price     Bid  \
# 0    SPXW231020C00200000  2023-07-07 10:18AM EDT   200.0     4197.59  4192.1
# 1    SPXW231020C00400000  2023-06-28 10:22AM EDT   400.0     3961.29  3994.6
# 2    SPXW231020C00600000   2023-06-27 2:20PM EDT   600.0     3774.80  3798.5
# 3     SPX231020C00800000  2023-05-23 11:53AM EDT   800.0     3379.00     0.0
# 4     SPX231020C01000000   2023-06-20 3:30PM EDT  1000.0     3392.20  3404.1
# ..                   ...                     ...     ...         ...     ...
# 222  SPXW231020C06000000  2023-06-09 11:29AM EDT  6000.0        0.05     0.0
# 223   SPX231020C06200000  2023-07-10 12:00PM EDT  6200.0        0.07     0.0
# 224   SPX231020C06400000   2023-06-06 3:13PM EDT  6400.0        0.06     0.0
# 225  SPXW231020C06600000  2023-05-25 10:39AM EDT  6600.0        0.07     0.0
# 226   SPX231020C06800000  2023-07-10 12:01PM EDT  6800.0        0.05     0.0
#
#          Ask  Change % Change Volume  Open Interest Implied Volatility  \
# 0    4196.10    0.00        -      2            167              0.00%
# 1    3998.60    0.00        -      3             61              0.00%
# 2    3802.50    0.00        -      6             40              0.00%
# 3       0.00    0.00        -      2              0              0.00%
# 4    3409.40    0.00        -   2500           2583            100.39%
# ..       ...     ...      ...    ...            ...                ...
# 222     0.15    0.00        -     10             90             18.90%
# 223     0.10   -0.01  -12.50%      2            250             20.04%
# 224     0.10    0.00        -      8            382             21.73%
# 225     0.10    0.00        -      -              2             23.34%
# 226     0.05   -0.02  -28.57%      4            417             23.73%
#
#            Expiration
# 0    October 20, 2023
# 1    October 20, 2023
# 2    October 20, 2023
# 3    October 20, 2023
# 4    October 20, 2023
# ..                ...
# 222  October 20, 2023
# 223  October 20, 2023
# 224  October 20, 2023
# 225  October 20, 2023
# 226  October 20, 2023
#
# [227 rows x 12 columns]

# %%
#concating all dataframes into a single one.
df = pd.concat(dfs, axis=0, ignore_index=True)
df.head()
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price     Bid  \
# 0  SPXW230714C01200000  2023-07-10 10:32AM EDT  1200.0     3205.33  3203.8
# 1  SPXW230714C02000000   2023-06-30 3:45PM EDT  2000.0     2455.75  2404.5
# 2  SPXW230714C02800000  2023-06-26 12:37PM EDT  2800.0     1544.75  1605.4
# 3  SPXW230714C02900000   2023-06-14 2:31PM EDT  2900.0     1454.60  1506.3
# 4  SPXW230714C03000000   2023-06-09 9:38AM EDT  3000.0     1314.73  1402.3
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility  \
# 0  3207.4  -30.19   -0.93%      2           2255            427.05%
# 1  2407.9    0.00        -      5             10            232.32%
# 2  1608.9    0.00        -     30              5            156.32%
# 3  1509.8    0.00        -      -             15            154.54%
# 4  1408.8    0.00        -      -              1            148.79%
#
#       Expiration
# 0  July 14, 2023
# 1  July 14, 2023
# 2  July 14, 2023
# 3  July 14, 2023
# 4  July 14, 2023

# %%
len(df)
# Out:
# 2206

# %% [markdown]
# One final transformation needs to be performed, which is to convert the 'Expiration' column into time left from today, in years.

# %%
df.columns.get_loc('Expiration')
# Out:
# 11

# %%
#an example on how to  change Expiration date, which is in string format, to Time to Expiration which is the number of days
#between today and Expiration date.

a = df.iloc[10,11]
print(a,type(a))
b = datetime.strptime(a,"%B %d, %Y").date()
print(b,type(b))

today = datetime.today().date()
print(today,type(today))

diff = (b - today)
print(diff,type(diff))
delta = int(diff.days)/252 #assuming there are 252 trading days in a calender year.
delta
# Out:
# July 14, 2023 <class 'str'>
# 2023-07-14 <class 'datetime.date'>
# 2023-07-10 <class 'datetime.date'>
# 4 days, 0:00:00 <class 'datetime.timedelta'>
# 0.015873015873015872

# %%
for i in range(len(df)):
    
    df.iloc[i,11] = int( (datetime.strptime(df.iloc[i,11],"%B %d, %Y").date() - today).days)/252

# %%
df.head()
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price     Bid  \
# 0  SPXW230714C01200000  2023-07-10 10:32AM EDT  1200.0     3205.33  3203.8
# 1  SPXW230714C02000000   2023-06-30 3:45PM EDT  2000.0     2455.75  2404.5
# 2  SPXW230714C02800000  2023-06-26 12:37PM EDT  2800.0     1544.75  1605.4
# 3  SPXW230714C02900000   2023-06-14 2:31PM EDT  2900.0     1454.60  1506.3
# 4  SPXW230714C03000000   2023-06-09 9:38AM EDT  3000.0     1314.73  1402.3
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility Expiration
# 0  3207.4  -30.19   -0.93%      2           2255            427.05%   0.015873
# 1  2407.9    0.00        -      5             10            232.32%   0.015873
# 2  1608.9    0.00        -     30              5            156.32%   0.015873
# 3  1509.8    0.00        -      -             15            154.54%   0.015873
# 4  1408.8    0.00        -      -              1            148.79%   0.015873

# %%
a = df.iloc[0,1][:10]
b = datetime.strptime(a,"%Y-%m-%d").date()

# %%
b
# Out:
# datetime.date(2023, 7, 10)

# %%
# get S&p 500 index price and add it to the dataframe!

import yfinance as yf

# Create a ticker object for the S&P 500 index
ticker = yf.Ticker('^GSPC')

# data = ticker.history(start='yyyy-mm-dd', end='yyyy-mm-dd')

# # Extract the closing price for the specific date
# closing_price = data['Close'].iloc[0]

# %%
data = ticker.history(period='2d')
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2023-07-07 00:00:00-04:00  4404.540039  4440.390137  4397.399902  4398.950195
# 2023-07-10 00:00:00-04:00  4394.229980  4412.600098  4389.919922  4401.080078
#
#                                Volume  Dividends  Stock Splits
# Date
# 2023-07-07 00:00:00-04:00  3630480000        0.0           0.0
# 2023-07-10 00:00:00-04:00  1228044000        0.0           0.0

# %%
df['Spot Price'] = 4398.950195

# %%
df.head()
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price     Bid  \
# 0  SPXW230714C01200000  2023-07-10 10:32AM EDT  1200.0     3205.33  3203.8
# 1  SPXW230714C02000000   2023-06-30 3:45PM EDT  2000.0     2455.75  2404.5
# 2  SPXW230714C02800000  2023-06-26 12:37PM EDT  2800.0     1544.75  1605.4
# 3  SPXW230714C02900000   2023-06-14 2:31PM EDT  2900.0     1454.60  1506.3
# 4  SPXW230714C03000000   2023-06-09 9:38AM EDT  3000.0     1314.73  1402.3
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility  \
# 0  3207.4  -30.19   -0.93%      2           2255            427.05%
# 1  2407.9    0.00        -      5             10            232.32%
# 2  1608.9    0.00        -     30              5            156.32%
# 3  1509.8    0.00        -      -             15            154.54%
# 4  1408.8    0.00        -      -              1            148.79%
#
#   Expiration   Spot Price
# 0   0.015873  4398.950195
# 1   0.015873  4398.950195
# 2   0.015873  4398.950195
# 3   0.015873  4398.950195
# 4   0.015873  4398.950195

# %%
#we will only look at the OTM calls!

df_otm = df[df['Spot Price'] < df['Strike']]
df_otm.head()
len(df_otm)
# Out:
# 817

# %%
df_otm.head()
# Out:
#            Contract Name        Last Trade Date  Strike  Last Price   Bid  \
# 107  SPXW230714C04400000  2023-07-10 1:45PM EDT  4400.0       29.70  29.5
# 108  SPXW230714C04405000  2023-07-10 1:35PM EDT  4405.0       26.50  26.5
# 109  SPXW230714C04410000  2023-07-10 1:44PM EDT  4410.0       23.80  23.7
# 110  SPXW230714C04415000  2023-07-10 1:30PM EDT  4415.0       21.70  21.7
# 111  SPXW230714C04420000  2023-07-10 1:41PM EDT  4420.0       18.72  19.0
#
#       Ask  Change % Change Volume  Open Interest Implied Volatility  \
# 107  29.7   -0.80   -2.62%   1469           3110             12.99%
# 108  26.8   -1.60   -5.69%    456            321             12.84%
# 109  23.9   -1.20   -4.80%   1118            441             12.61%
# 110  21.9   -1.05   -4.62%    260           1087             12.75%
# 111  19.2   -1.64   -8.06%    496            747             12.47%
#
#     Expiration   Spot Price
# 107   0.015873  4398.950195
# 108   0.015873  4398.950195
# 109   0.015873  4398.950195
# 110   0.015873  4398.950195
# 111   0.015873  4398.950195

# %%
df_otm.to_csv("OTM_Calls.csv")
